# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
filepath = "../input/covid19-in-usa/us_states_covid19_daily.csv"

print(filepath)

us_states_data = pd.read_csv(filepath, index_col="date", parse_dates=True)

sns.regplot(x=us_states_data['total'], y=us_states_data['death'])
# Out:
# ../input/covid19-in-usa/us_states_covid19_daily.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b147c0c9cacc> in <module>
#       5 us_states_data = pd.read_csv(filepath, index_col="date", parse_dates=True)
#       6
# ----> 7 sns.regplot(x=my_data['total'], y=my_data['death'])
#
# NameError: name 'my_data' is not defined
